# %%
import os
import sys
import tensorflow as tf
import numpy as np
import math
import timeit
import scipy

#import matplotlib.pyplot as plt

import provider
import TR
#%matplotlib inline

# %%
USE_GPU = True

if USE_GPU:
    device = '/device:GPU:0'
else:
    device = '/cpu:0'

# Constant to control how often we print when training models
print_every = 100

print('Using device: ', device)
# Out:
# Using device:  /device:GPU:0

# %%
class CentralNet(tf.keras.Model):
    def __init__(self, channel_1, channel_2,channel_3,channel_4, num_classes,c1,c2,c3,c4):
        super().__init__()

#         pass
        initializer = tf.variance_scaling_initializer(scale=2.0)
        self.conv1 = tf.layers.Conv2D(channel_1, kernel_size=(3,3), 
                                      strides=(1,1),padding="SAME",
                                      activation = tf.nn.relu,use_bias=True,
                                      kernel_initializer = initializer,
                                      bias_initializer=tf.zeros_initializer())
        self.conv2 = tf.layers.Conv2D(channel_1, kernel_size=(3,3), 
                                      strides=(1,1),padding="SAME",
                                      activation = tf.nn.relu,use_bias=True,
                                      kernel_initializer = initializer,
                                      bias_initializer=tf.zeros_initializer())
        self.maxpool1 = tf.layers.MaxPooling2D(pool_size = (2,2), 
                               strides = (2,2), padding='SAME')
        
        self.conv3 = tf.layers.Conv2D(channel_2, kernel_size=(3,3), 
                                      strides=(1,1),padding="SAME",
                                      activation = tf.nn.relu,use_bias=True,
                                      kernel_initializer = initializer,
                                      bias_initializer=tf.zeros_initializer())        
        self.conv4 = tf.layers.Conv2D(channel_2, kernel_size=(3,3), 
                                      strides=(1,1),padding="SAME",
                                      activation = tf.nn.relu,use_bias=True,
                                      kernel_initializer = initializer,
                                      bias_initializer=tf.zeros_initializer())
        self.maxpool2 = tf.layers.MaxPooling2D(pool_size = (2,2), 
                               strides = (2,2), padding='SAME')
        
        self.conv5 = tf.layers.Conv2D(channel_3, kernel_size=(3,3),
                                      strides=(1,1),padding="SAME",
                                      activation = tf.nn.relu,use_bias=True,
                                      kernel_initializer = initializer,
                                      bias_initializer=tf.zeros_initializer()) # conv3-256
        self.conv6 = tf.layers.Conv2D(channel_3, kernel_size=(3,3),
                                      strides=(1,1),padding="SAME",
                                      activation = tf.nn.relu,use_bias=True,
                                      kernel_initializer = initializer,
                                      bias_initializer=tf.zeros_initializer()) # conv3-256
        self.conv7 = tf.layers.Conv2D(channel_3, kernel_size=(3,3),
                                      strides=(1,1),padding="SAME",
                                      activation = tf.nn.relu,use_bias=True,
                                      kernel_initializer = initializer,
                                      bias_initializer=tf.zeros_initializer()) # conv3-256
        self.maxpool3 = tf.layers.MaxPooling2D(pool_size = (2,2), 
                               strides = (2,2), padding='SAME')

        self.conv8 = tf.layers.Conv2D(channel_4, kernel_size=(3,3),
                                      strides=(1,1),padding="SAME",
                                      activation = tf.nn.relu,use_bias=True,
                                      kernel_initializer = initializer,
                                      bias_initializer=tf.zeros_initializer()) # conv3-512
        self.conv9 = tf.layers.Conv2D(channel_4, kernel_size=(3,3),
                                      strides=(1,1),padding="SAME",
                                      activation = tf.nn.relu,use_bias=True,
                                      kernel_initializer = initializer,
                                      bias_initializer=tf.zeros_initializer()) # conv3-512
        self.conv10 = tf.layers.Conv2D(channel_4, kernel_size=(3,3),
                                      strides=(1,1),padding="SAME",
                                      activation = tf.nn.relu,use_bias=True,
                                      kernel_initializer = initializer,
                                      bias_initializer=tf.zeros_initializer()) # conv3-512
        self.maxpool4 = tf.layers.MaxPooling2D(pool_size = (2,2), 
                               strides = (2,2), padding='SAME')

        self.conv11 = tf.layers.Conv2D(channel_4, kernel_size=(3,3),
                                      strides=(1,1),padding="SAME",
                                      activation = tf.nn.relu,use_bias=True,
                                      kernel_initializer = initializer,
                                      bias_initializer=tf.zeros_initializer()) # conv3-512
        self.conv12 = tf.layers.Conv2D(channel_4, kernel_size=(3,3),
                                      strides=(1,1),padding="SAME",
                                      activation = tf.nn.relu,use_bias=True,
                                      kernel_initializer = initializer,
                                      bias_initializer=tf.zeros_initializer()) # conv3-512
        self.conv13 = tf.layers.Conv2D(channel_4, kernel_size=(3,3),
                                      strides=(1,1),padding="SAME",
                                      activation = tf.nn.relu,use_bias=True,
                                      kernel_initializer = initializer,
                                      bias_initializer=tf.zeros_initializer()) # conv3-512
        self.maxpool5 = tf.layers.MaxPooling2D(pool_size = (2,2), 
                               strides = (2,2), padding='SAME')
                                     
        self.fc4c1 = tf.layers.Dense(c1, activation=tf.nn.relu,use_bias=False,
                                  kernel_initializer=initializer,
                                  bias_initializer=tf.zeros_initializer())
        self.c14c2 = tf.layers.Dense(c2, activation=tf.nn.relu,use_bias=False,
                                  kernel_initializer=initializer,
                                  bias_initializer=tf.zeros_initializer())
        self.fc4c2 = tf.layers.Dense(c2, activation=tf.nn.relu,use_bias=False,
                                  kernel_initializer=initializer,
                                  bias_initializer=tf.zeros_initializer())
        self.c24c3 = tf.layers.Dense(c3, activation=tf.nn.relu,use_bias=False,
                                  kernel_initializer=initializer,
                                  bias_initializer=tf.zeros_initializer())
        self.fc4c3 = tf.layers.Dense(c3, activation=tf.nn.relu,use_bias=False,
                                  kernel_initializer=initializer,
                                  bias_initializer=tf.zeros_initializer())
        self.c34c4 = tf.layers.Dense(c4, activation=tf.nn.relu,use_bias=False,
                                  kernel_initializer=initializer,
                                  bias_initializer=tf.zeros_initializer())
        self.fc4c4 = tf.layers.Dense(c4, activation=tf.nn.relu,use_bias=False,
                                  kernel_initializer=initializer,
                                  bias_initializer=tf.zeros_initializer())
        self.c44c5 = tf.layers.Dense(4096, activation=tf.nn.relu,use_bias=False,
                                  kernel_initializer=initializer,
                                  bias_initializer=tf.zeros_initializer())
        
        self.flatten = tf.keras.layers.Flatten()
        
        self.fc1=tf.layers.Dense(4096, activation = tf.nn.relu, 
                        kernel_initializer=initializer)
        self.fc2=tf.layers.Dense(4096, activation = tf.nn.relu, 
                        kernel_initializer=initializer)
        self.fc3=tf.layers.Dense(1000, activation = tf.nn.relu, 
                        kernel_initializer=initializer)
        self.fc4=tf.layers.Dense(num_classes, activation = None, 
                        kernel_initializer=initializer)
     
    def call(self, x1,x2, training=None):
        scores = None
        ###

        x1_conv1 = self.conv1(x1)
        x1_conv2 = self.conv2(x1_conv1)
        x1_maxpool1 = self.maxpool1(x1_conv2)
        h1_x1=self.flatten(x1_maxpool1)
        x2_conv1 = self.conv1(x2)
        x2_conv2 = self.conv2(x2_conv1)
        x2_maxpool1 = self.maxpool1(x2_conv2)
        h1_x2=self.flatten(x2_maxpool1)
        hc1=self.fc4c1(h1_x1)+self.fc4c1(h1_x2)
        ##conv3-64
        x1_conv3 = self.conv3(x1_maxpool1)
        x1_conv4 = self.conv4(x1_conv3)
        x1_maxpool2 = self.maxpool2(x1_conv4)
        h2_x1=self.flatten(x1_maxpool2)
        x2_conv3 = self.conv3(x2_maxpool1)
        x2_conv4 = self.conv4(x2_conv3)
        x2_maxpool2 = self.maxpool2(x2_conv4)
        h2_x2=self.flatten(x2_maxpool2)
        hc2=self.fc4c2(h2_x1)+self.fc4c2(h2_x2)+self.c14c2(hc1)
        ##conv3-128
        x1_conv5 = self.conv5(x1_maxpool2)
        x1_conv6 = self.conv6(x1_conv5)
        x1_conv7 = self.conv7(x1_conv6)
        x1_maxpool3 = self.maxpool3(x1_conv7)
        h3_x1=self.flatten(x1_maxpool3)
        x2_conv5 = self.conv5(x2_maxpool2)
        x2_conv6 = self.conv6(x2_conv5)
        x2_conv7= self.conv7(x2_conv6)
        x2_maxpool3= self.maxpool3(x2_conv7)
        h3_x2=self.flatten(x2_maxpool3)
        hc3=self.fc4c3(h3_x1)+self.fc4c3(h3_x2)+self.c24c3(hc2)
        ##conv3-256
        x1_conv8 = self.conv8(x1_maxpool3)
        x1_conv9 = self.conv9(x1_conv8)
        x1_conv10 = self.conv10(x1_conv9)
        x1_maxpool4 = self.maxpool4(x1_conv10)
        h4_x1=self.flatten(x1_maxpool4)
        x2_conv8 = self.conv8(x2_maxpool3)
        x2_conv9 = self.conv9(x2_conv8)
        x2_conv10 = self.conv10(x2_conv9)
        x2_maxpool4= self.maxpool4(x2_conv10)
        h4_x2=self.flatten(x2_maxpool4)
        hc4=self.fc4c4(h4_x1)+self.fc4c4(h4_x2)+self.c34c4(hc3)
        ##conv3-512
        x1_conv11 = self.conv11(x1_maxpool4)
        x1_conv12 = self.conv12(x1_conv11)
        x1_conv13 = self.conv13(x1_conv12)
        x1_maxpool5 = self.maxpool5(x1_conv13)
        h5_x1=self.flatten(x1_maxpool5)
        x2_conv11 = self.conv11(x2_maxpool4)
        x2_conv12 = self.conv12(x2_conv11)
        x2_conv13 = self.conv13(x2_conv12)
        x2_maxpool5= self.maxpool5(x2_conv13)
        h5_x2=self.flatten(x2_maxpool5)
        hc5=self.fc1(h5_x1)+self.fc1(h5_x2)+self.c44c5(hc4)    #x1 and x2 have the same size    #4096
        dense2=self.fc2(hc5) #4096
        dense3=self.fc3(dense2)#1000
        scores= self.fc4(dense3)#num_classes
        return scores

def placeholder_inputs(batch_size, img_rows=66, img_cols=200, points=16384, separately=False):
    imgs_pl = tf.placeholder(tf.float32, shape=(batch_size, img_rows, img_cols, 3))
    pts_pl = tf.placeholder(tf.float32, shape=(batch_size, points, 3))
    if separately:
        speeds_pl = tf.placeholder(tf.float32, shape=(batch_size))
        angles_pl = tf.placeholder(tf.float32, shape=(batch_size))
        labels_pl = [speeds_pl, angles_pl]
    labels_pl = tf.placeholder(tf.float32, shape=(batch_size, 2))
    return imgs_pl, pts_pl, labels_pl


def get_loss(pred, label, l2_weight=0.0001):
    diff = tf.square(tf.subtract(pred, label))
    train_vars = tf.trainable_variables()
    l2_loss = tf.add_n([tf.nn.l2_loss(v) for v in train_vars[1:]]) * l2_weight
    loss = tf.reduce_mean(diff + l2_loss)

    return loss

# %%
tf.reset_default_graph()

channel_1, channel_2,channel_3,channel_4, num_classes,c1,c2,c3,c4=64,128,256,512,10,64,128,256,512
model = CentralNet(channel_1, channel_2,channel_3,channel_4, num_classes,c1,c2,c3,c4)
with tf.device(device):
    x1 = tf.zeros((64, 32, 32,3))
    x2 = tf.zeros((64, 32, 32,3))
    scores = model(x1,x2)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    scores_np = sess.run(scores)
    print(scores_np.shape)

# %%
BATCH_SIZE=8
MAX_EPOCH=1
learning_rate = 3e-5
channel_1, channel_2,channel_3,channel_4, num_classes,c1,c2,c3,c4=64,128,256,512,2,64,128,256,512

def model_init_fn(inputs1,inputs2, is_training):
    model = None

    model = CentralNet(channel_1, channel_2,channel_3,channel_4, num_classes,c1,c2,c3,c4)

    return model(inputs1,inputs2)

def optimizer_init_fn():
    optimizer = None

    optimizer = tf.train.AdamOptimizer()

    return optimizer

TR.train_part34(model_init_fn, optimizer_init_fn,100,device,BATCH_SIZE)
# Out:
# Starting epoch 0
# mean loss: 115723.451701
# accuracy (angle): 0.095238
# accuracy (speed): 0.161376
# eval mean loss: 0.682393
# eval accuracy (angle): 0.135638
# eval accuracy (speed): 0.223404
# Starting epoch 1
# mean loss: 0.860238
# accuracy (angle): 0.124008
# accuracy (speed): 0.201720
# eval mean loss: 0.605269
# eval accuracy (angle): 0.094415
# eval accuracy (speed): 0.259309
# Starting epoch 2
# mean loss: 0.748471
# accuracy (angle): 0.132937
# accuracy (speed): 0.200728
# eval mean loss: 0.407079
# eval accuracy (angle): 0.162234
# eval accuracy (speed): 0.340426
# Starting epoch 3
# mean loss: 0.521057
# accuracy (angle): 0.168320
# accuracy (speed): 0.287368
# eval mean loss: 0.355005
# eval accuracy (angle): 0.190160
# eval accuracy (speed): 0.344415
# Starting epoch 4
# mean loss: 0.448503
# accuracy (angle): 0.185185
# accuracy (speed): 0.309193
# eval mean loss: 0.245980
# eval accuracy (angle): 0.220745
# eval accuracy (speed): 0.414894
# Starting epoch 5
# mean loss: 0.421437
# accuracy (angle): 0.200066
# accuracy (speed): 0.303571
# eval mean loss: 0.231833
# eval accuracy (angle): 0.240691
# eval accuracy (speed): 0.404255
# Starting epoch 6
# mean loss: 0.352971
# accuracy (angle): 0.232804
# accuracy (speed): 0.337963
# eval mean loss: 0.195121
# eval accuracy (angle): 0.248670
# eval accuracy (speed): 0.437500
# Starting epoch 7
# mean loss: 0.302498
# accuracy (angle): 0.244048
# accuracy (speed): 0.372685
# eval mean loss: 0.170174
# eval accuracy (angle): 0.279255
# eval accuracy (speed): 0.461436
# Starting epoch 8
# mean loss: 0.288290
# accuracy (angle): 0.254630
# accuracy (speed): 0.378307
# eval mean loss: 0.187191
# eval accuracy (angle): 0.264628
# eval accuracy (speed): 0.434840
# Starting epoch 9
# mean loss: 0.282908
# accuracy (angle): 0.247354
# accuracy (speed): 0.371032
# eval mean loss: 0.246815
# eval accuracy (angle): 0.279255
# eval accuracy (speed): 0.389628
# Starting epoch 10
# mean loss: 0.375316
# accuracy (angle): 0.242063
# accuracy (speed): 0.358135
# eval mean loss: 0.375189
# eval accuracy (angle): 0.231383
# eval accuracy (speed): 0.394947
# Starting epoch 11
# mean loss: 0.393737
# accuracy (angle): 0.233796
# accuracy (speed): 0.376984
# eval mean loss: 0.271461
# eval accuracy (angle): 0.255319
# eval accuracy (speed): 0.444149
# Starting epoch 12
# mean loss: 0.338668
# accuracy (angle): 0.264550
# accuracy (speed): 0.397487
# eval mean loss: 0.252252
# eval accuracy (angle): 0.236702
# eval accuracy (speed): 0.444149
# Starting epoch 13
# mean loss: 0.336938
# accuracy (angle): 0.263228
# accuracy (speed): 0.405754
# eval mean loss: 0.224575
# eval accuracy (angle): 0.232713
# eval accuracy (speed): 0.461436
# Starting epoch 14
# mean loss: 0.348850
# accuracy (angle): 0.240410
# accuracy (speed): 0.390212
# eval mean loss: 0.212647
# eval accuracy (angle): 0.242021
# eval accuracy (speed): 0.470745
# Starting epoch 15
# mean loss: 0.276599
# accuracy (angle): 0.257606
# accuracy (speed): 0.432540
# eval mean loss: 0.201882
# eval accuracy (angle): 0.243351
# eval accuracy (speed): 0.460106
# Starting epoch 16
# mean loss: 0.280814
# accuracy (angle): 0.260251
# accuracy (speed): 0.416336
# eval mean loss: 0.176828
# eval accuracy (angle): 0.297872
# eval accuracy (speed): 0.492021
# Starting epoch 17
# mean loss: 0.260641
# accuracy (angle): 0.275794
# accuracy (speed): 0.416997
# eval mean loss: 0.212766
# eval accuracy (angle): 0.287234
# eval accuracy (speed): 0.429521
# Starting epoch 18
# mean loss: 0.257571
# accuracy (angle): 0.271164
# accuracy (speed): 0.462963
# eval mean loss: 0.347632
# eval accuracy (angle): 0.231383
# eval accuracy (speed): 0.473404
# Starting epoch 19
# mean loss: 0.247096
# accuracy (angle): 0.278770
# accuracy (speed): 0.446429
# eval mean loss: 0.222368
# eval accuracy (angle): 0.279255
# eval accuracy (speed): 0.529255
# Starting epoch 20
# mean loss: 0.274337
# accuracy (angle): 0.262235
# accuracy (speed): 0.449074
# eval mean loss: 0.258084
# eval accuracy (angle): 0.247340
# eval accuracy (speed): 0.498670
# Starting epoch 21
# mean loss: 0.263985
# accuracy (angle): 0.272156
# accuracy (speed): 0.456680
# eval mean loss: 0.205020
# eval accuracy (angle): 0.304521
# eval accuracy (speed): 0.527926
# Starting epoch 22
# mean loss: 0.351854
# accuracy (angle): 0.250331
# accuracy (speed): 0.434854
# eval mean loss: 0.248742
# eval accuracy (angle): 0.253989
# eval accuracy (speed): 0.534574
# Starting epoch 23
# mean loss: 0.312843
# accuracy (angle): 0.249008
# accuracy (speed): 0.469577
# eval mean loss: 0.174304
# eval accuracy (angle): 0.280585
# eval accuracy (speed): 0.541223
# Starting epoch 24
# mean loss: 0.294792
# accuracy (angle): 0.267526
# accuracy (speed): 0.485780
# eval mean loss: 0.215584
# eval accuracy (angle): 0.299202
# eval accuracy (speed): 0.531915
# Starting epoch 25
# mean loss: 0.276853
# accuracy (angle): 0.268849
# accuracy (speed): 0.458333
# eval mean loss: 0.221973
# eval accuracy (angle): 0.284574
# eval accuracy (speed): 0.541223
# Starting epoch 26
# mean loss: 0.244263
# accuracy (angle): 0.300595
# accuracy (speed): 0.499339
# eval mean loss: 0.211175
# eval accuracy (angle): 0.307181
# eval accuracy (speed): 0.561170
# Starting epoch 27
# mean loss: 0.235364
# accuracy (angle): 0.290013
# accuracy (speed): 0.485780
# eval mean loss: 0.196440
# eval accuracy (angle): 0.296543
# eval accuracy (speed): 0.567819
# Starting epoch 28
# mean loss: 0.202551
# accuracy (angle): 0.313492
# accuracy (speed): 0.525463
# eval mean loss: 0.181127
# eval accuracy (angle): 0.327128
# eval accuracy (speed): 0.565160
# Starting epoch 29
# mean loss: 0.232355
# accuracy (angle): 0.317130
# accuracy (speed): 0.521164
# eval mean loss: 0.156781
# eval accuracy (angle): 0.287234
# eval accuracy (speed): 0.579787
# Starting epoch 30
# mean loss: 0.201025
# accuracy (angle): 0.331680
# accuracy (speed): 0.534061
# eval mean loss: 0.159543
# eval accuracy (angle): 0.320479
# eval accuracy (speed): 0.583777
# Starting epoch 31
# mean loss: 0.184489
# accuracy (angle): 0.339616
# accuracy (speed): 0.561839
# eval mean loss: 0.098148
# eval accuracy (angle): 0.360372
# eval accuracy (speed): 0.640957
# Starting epoch 32
# mean loss: 0.176921
# accuracy (angle): 0.346561
# accuracy (speed): 0.574735
# eval mean loss: 0.129405
# eval accuracy (angle): 0.368351
# eval accuracy (speed): 0.566489
# Starting epoch 33
# mean loss: 0.173184
# accuracy (angle): 0.343915
# accuracy (speed): 0.560516
# eval mean loss: 0.163297
# eval accuracy (angle): 0.341755
# eval accuracy (speed): 0.571809
# Starting epoch 34
# mean loss: 0.194204
# accuracy (angle): 0.346230
# accuracy (speed): 0.551918
# eval mean loss: 0.163909
# eval accuracy (angle): 0.340426
# eval accuracy (speed): 0.594415
# Starting epoch 35
# mean loss: 0.172757
# accuracy (angle): 0.348876
# accuracy (speed): 0.569775
# eval mean loss: 0.161270
# eval accuracy (angle): 0.347074
# eval accuracy (speed): 0.619681
# Starting epoch 36
# mean loss: 0.191288
# accuracy (angle): 0.327381
# accuracy (speed): 0.547619
# eval mean loss: 0.176236
# eval accuracy (angle): 0.339096
# eval accuracy (speed): 0.575798
# Starting epoch 37
# mean loss: 0.180297
# accuracy (angle): 0.344246
# accuracy (speed): 0.577050
# eval mean loss: 0.141497
# eval accuracy (angle): 0.355053
# eval accuracy (speed): 0.639628
# Starting epoch 38
# mean loss: 0.179394
# accuracy (angle): 0.349206
# accuracy (speed): 0.574405
# eval mean loss: 0.155245
# eval accuracy (angle): 0.363032
# eval accuracy (speed): 0.625000
# Starting epoch 39
# mean loss: 0.168306
# accuracy (angle): 0.379960
# accuracy (speed): 0.599868
# eval mean loss: 0.093149
# eval accuracy (angle): 0.398936
# eval accuracy (speed): 0.668883
# Starting epoch 40
# mean loss: 0.178388
# accuracy (angle): 0.372354
# accuracy (speed): 0.586640
# eval mean loss: 0.112084
# eval accuracy (angle): 0.393617
# eval accuracy (speed): 0.627660
# Starting epoch 41
# mean loss: 0.161454
# accuracy (angle): 0.364749
# accuracy (speed): 0.613426
# eval mean loss: 0.115973
# eval accuracy (angle): 0.382979
# eval accuracy (speed): 0.659574
# Starting epoch 42
# mean loss: 0.218730
# accuracy (angle): 0.334656
# accuracy (speed): 0.545635
# eval mean loss: 0.179918
# eval accuracy (angle): 0.339096
# eval accuracy (speed): 0.638298
# Starting epoch 43
# mean loss: 0.169339
# accuracy (angle): 0.363095
# accuracy (speed): 0.586971
# eval mean loss: 0.141124
# eval accuracy (angle): 0.384309
# eval accuracy (speed): 0.652926
# Starting epoch 44
# mean loss: 0.163817
# accuracy (angle): 0.361442
# accuracy (speed): 0.581019
# eval mean loss: 0.152814
# eval accuracy (angle): 0.388298
# eval accuracy (speed): 0.593085
# Starting epoch 45
# mean loss: 0.187781
# accuracy (angle): 0.373677
# accuracy (speed): 0.560185
# eval mean loss: 0.137281
# eval accuracy (angle): 0.385638
# eval accuracy (speed): 0.630319
# Starting epoch 46
# mean loss: 0.193730
# accuracy (angle): 0.371362
# accuracy (speed): 0.561508
# eval mean loss: 0.120249
# eval accuracy (angle): 0.406915
# eval accuracy (speed): 0.655585
# Starting epoch 47
# mean loss: 0.172655
# accuracy (angle): 0.392857
# accuracy (speed): 0.581349
# eval mean loss: 0.091484
# eval accuracy (angle): 0.412234
# eval accuracy (speed): 0.670213
# Starting epoch 48
# mean loss: 0.158142
# accuracy (angle): 0.388558
# accuracy (speed): 0.610119
# eval mean loss: 0.084426
# eval accuracy (angle): 0.433511
# eval accuracy (speed): 0.690160
# Starting epoch 49
# mean loss: 0.166168
# accuracy (angle): 0.388558
# accuracy (speed): 0.616071
# eval mean loss: 0.114580
# eval accuracy (angle): 0.396277
# eval accuracy (speed): 0.676862
# Starting epoch 50
# mean loss: 0.152609
# accuracy (angle): 0.399471
# accuracy (speed): 0.625000
# eval mean loss: 0.150245
# eval accuracy (angle): 0.406915
# eval accuracy (speed): 0.675532
# Starting epoch 51
# mean loss: 0.154406
# accuracy (angle): 0.396495
# accuracy (speed): 0.609458
# eval mean loss: 0.136334
# eval accuracy (angle): 0.382979
# eval accuracy (speed): 0.686170
# Starting epoch 52
# mean loss: 0.145244
# accuracy (angle): 0.382937
# accuracy (speed): 0.634590
# eval mean loss: 0.136116
# eval accuracy (angle): 0.414894
# eval accuracy (speed): 0.679521
# Starting epoch 53
# mean loss: 0.161064
# accuracy (angle): 0.385251
# accuracy (speed): 0.604167
# eval mean loss: 0.156348
# eval accuracy (angle): 0.400266
# eval accuracy (speed): 0.650266
# Starting epoch 54
# mean loss: 0.172219
# accuracy (angle): 0.387566
# accuracy (speed): 0.627315
# eval mean loss: 0.149574
# eval accuracy (angle): 0.353723
# eval accuracy (speed): 0.609043
# Starting epoch 55
# mean loss: 0.173465
# accuracy (angle): 0.371032
# accuracy (speed): 0.580688
# eval mean loss: 0.108469
# eval accuracy (angle): 0.401596
# eval accuracy (speed): 0.625000
# Starting epoch 56
# mean loss: 0.152756
# accuracy (angle): 0.389881
# accuracy (speed): 0.611772
# eval mean loss: 0.079450
# eval accuracy (angle): 0.444149
# eval accuracy (speed): 0.704787
# Starting epoch 57
# mean loss: 0.156150
# accuracy (angle): 0.416336
# accuracy (speed): 0.633598
# eval mean loss: 0.115967
# eval accuracy (angle): 0.422872
# eval accuracy (speed): 0.683511
# Starting epoch 58
# mean loss: 0.188004
# accuracy (angle): 0.370040
# accuracy (speed): 0.579034
# eval mean loss: 0.153937
# eval accuracy (angle): 0.394947
# eval accuracy (speed): 0.590426
# Starting epoch 59
# mean loss: 0.187840
# accuracy (angle): 0.358466
# accuracy (speed): 0.567130
# eval mean loss: 0.133790
# eval accuracy (angle): 0.410904
# eval accuracy (speed): 0.670213
# Starting epoch 60
# mean loss: 0.163717
# accuracy (angle): 0.381944
# accuracy (speed): 0.571759
# eval mean loss: 0.147083
# eval accuracy (angle): 0.371011
# eval accuracy (speed): 0.635638
# Starting epoch 61
# mean loss: 0.179904
# accuracy (angle): 0.382937
# accuracy (speed): 0.584987
# eval mean loss: 0.216162
# eval accuracy (angle): 0.359043
# eval accuracy (speed): 0.589096
# Starting epoch 62
# mean loss: 0.177519
# accuracy (angle): 0.375331
# accuracy (speed): 0.595569
# eval mean loss: 0.128203
# eval accuracy (angle): 0.418883
# eval accuracy (speed): 0.686170
# Starting epoch 63
# mean loss: 0.161430
# accuracy (angle): 0.396825
# accuracy (speed): 0.623347
# eval mean loss: 0.105236
# eval accuracy (angle): 0.434840
# eval accuracy (speed): 0.651596
# Starting epoch 64
# mean loss: 0.149697
# accuracy (angle): 0.410053
# accuracy (speed): 0.627646
# eval mean loss: 0.079973
# eval accuracy (angle): 0.454787
# eval accuracy (speed): 0.698138
# Starting epoch 65
# mean loss: 0.142544
# accuracy (angle): 0.430886
# accuracy (speed): 0.641534
# eval mean loss: 0.080219
# eval accuracy (angle): 0.497340
# eval accuracy (speed): 0.760638
# Starting epoch 66
# mean loss: 0.134194
# accuracy (angle): 0.439153
# accuracy (speed): 0.665013
# eval mean loss: 0.159227
# eval accuracy (angle): 0.441489
# eval accuracy (speed): 0.679521
# Starting epoch 67
# mean loss: 0.158936
# accuracy (angle): 0.435185
# accuracy (speed): 0.628638
# eval mean loss: 0.125296
# eval accuracy (angle): 0.416223
# eval accuracy (speed): 0.682181
# Starting epoch 68
# mean loss: 0.155014
# accuracy (angle): 0.413690
# accuracy (speed): 0.614418
# eval mean loss: 0.165570
# eval accuracy (angle): 0.409574
# eval accuracy (speed): 0.636968
# Starting epoch 69
# mean loss: 0.178817
# accuracy (angle): 0.424934
# accuracy (speed): 0.632937
# eval mean loss: 0.155261
# eval accuracy (angle): 0.402926
# eval accuracy (speed): 0.638298
# Starting epoch 70
# mean loss: 0.187819
# accuracy (angle): 0.392526
# accuracy (speed): 0.584656
# eval mean loss: 0.182905
# eval accuracy (angle): 0.293883
# eval accuracy (speed): 0.595745
# Starting epoch 71
# mean loss: 0.157389
# accuracy (angle): 0.421958
# accuracy (speed): 0.625331
# eval mean loss: 0.113661
# eval accuracy (angle): 0.437500
# eval accuracy (speed): 0.694149
# Starting epoch 72
# mean loss: 0.154507
# accuracy (angle): 0.439484
# accuracy (speed): 0.652778
# eval mean loss: 0.091273
# eval accuracy (angle): 0.494681
# eval accuracy (speed): 0.715426
# Starting epoch 73
# mean loss: 0.134159
# accuracy (angle): 0.436839
# accuracy (speed): 0.632275
# eval mean loss: 0.075974
# eval accuracy (angle): 0.474734
# eval accuracy (speed): 0.767287
# Starting epoch 74
# mean loss: 0.250772
# accuracy (angle): 0.340939
# accuracy (speed): 0.564815
# eval mean loss: 0.147663
# eval accuracy (angle): 0.349734
# eval accuracy (speed): 0.623670
# Starting epoch 75
# mean loss: 0.182498
# accuracy (angle): 0.365741
# accuracy (speed): 0.586640
# eval mean loss: 0.133753
# eval accuracy (angle): 0.420213
# eval accuracy (speed): 0.676862
# Starting epoch 76
# mean loss: 0.139552
# accuracy (angle): 0.416005
# accuracy (speed): 0.639220
# eval mean loss: 0.142485
# eval accuracy (angle): 0.408245
# eval accuracy (speed): 0.650266
# Starting epoch 77
# mean loss: 0.144901
# accuracy (angle): 0.439153
# accuracy (speed): 0.661376
# eval mean loss: 0.116404
# eval accuracy (angle): 0.434840
# eval accuracy (speed): 0.707447
# Starting epoch 78
# mean loss: 0.148091
# accuracy (angle): 0.426918
# accuracy (speed): 0.662037
# eval mean loss: 0.135737
# eval accuracy (angle): 0.409574
# eval accuracy (speed): 0.642287
# Starting epoch 79
# mean loss: 0.155715
# accuracy (angle): 0.437831
# accuracy (speed): 0.628968
# eval mean loss: 0.104115
# eval accuracy (angle): 0.434840
# eval accuracy (speed): 0.694149
# Starting epoch 80
# mean loss: 0.137212
# accuracy (angle): 0.452712
# accuracy (speed): 0.667989
# eval mean loss: 0.080025
# eval accuracy (angle): 0.457447
# eval accuracy (speed): 0.700798
# Starting epoch 81
# mean loss: 0.130948
# accuracy (angle): 0.456349
# accuracy (speed): 0.666997
# eval mean loss: 0.081779
# eval accuracy (angle): 0.497340
# eval accuracy (speed): 0.756649
# Starting epoch 82
# mean loss: 0.134224
# accuracy (angle): 0.451389
# accuracy (speed): 0.666997
# eval mean loss: 0.116290
# eval accuracy (angle): 0.492021
# eval accuracy (speed): 0.750000
# Starting epoch 83
# mean loss: 0.125383
# accuracy (angle): 0.452381
# accuracy (speed): 0.675926
# eval mean loss: 0.117764
# eval accuracy (angle): 0.474734
# eval accuracy (speed): 0.711436
# Starting epoch 84
# mean loss: 0.123075
# accuracy (angle): 0.453373
# accuracy (speed): 0.667328
# eval mean loss: 0.138952
# eval accuracy (angle): 0.472074
# eval accuracy (speed): 0.707447
# Starting epoch 85
# mean loss: 0.137584
# accuracy (angle): 0.468585
# accuracy (speed): 0.683201
# eval mean loss: 0.110026
# eval accuracy (angle): 0.449468
# eval accuracy (speed): 0.723404
# Starting epoch 86
# mean loss: 0.133215
# accuracy (angle): 0.486111
# accuracy (speed): 0.698082
# eval mean loss: 0.237453
# eval accuracy (angle): 0.207447
# eval accuracy (speed): 0.505319
# Starting epoch 87
# mean loss: 0.144277
# accuracy (angle): 0.445437
# accuracy (speed): 0.662037
# eval mean loss: 0.140909
# eval accuracy (angle): 0.398936
# eval accuracy (speed): 0.626330
# Starting epoch 88
# mean loss: 0.120308
# accuracy (angle): 0.470238
# accuracy (speed): 0.693122
# eval mean loss: 0.079282
# eval accuracy (angle): 0.474734
# eval accuracy (speed): 0.735372
# Starting epoch 89
# mean loss: 0.162057
# accuracy (angle): 0.423942
# accuracy (speed): 0.657738
# eval mean loss: 0.110924
# eval accuracy (angle): 0.337766
# eval accuracy (speed): 0.714096
# Starting epoch 90
# mean loss: 0.145516
# accuracy (angle): 0.440807
# accuracy (speed): 0.683201
# eval mean loss: 0.122980
# eval accuracy (angle): 0.434840
# eval accuracy (speed): 0.691489
# Starting epoch 91
# mean loss: 0.130299
# accuracy (angle): 0.470899
# accuracy (speed): 0.686839
# eval mean loss: 0.116812
# eval accuracy (angle): 0.417553
# eval accuracy (speed): 0.680851
# Starting epoch 92
# mean loss: 0.121397
# accuracy (angle): 0.474206
# accuracy (speed): 0.699735
# eval mean loss: 0.189692
# eval accuracy (angle): 0.365691
# eval accuracy (speed): 0.627660
# Starting epoch 93
# mean loss: 0.144449
# accuracy (angle): 0.453704
# accuracy (speed): 0.668981
# eval mean loss: 0.134875
# eval accuracy (angle): 0.417553
# eval accuracy (speed): 0.684840
# Starting epoch 94
# mean loss: 0.150652
# accuracy (angle): 0.487765
# accuracy (speed): 0.696429
# eval mean loss: 0.125407
# eval accuracy (angle): 0.414894
# eval accuracy (speed): 0.668883
# Starting epoch 95
# mean loss: 0.133683
# accuracy (angle): 0.479167
# accuracy (speed): 0.680556
# eval mean loss: 0.092597
# eval accuracy (angle): 0.461436
# eval accuracy (speed): 0.738032
# Starting epoch 96
# mean loss: 0.152701
# accuracy (angle): 0.436177
# accuracy (speed): 0.647817
# eval mean loss: 0.096777
# eval accuracy (angle): 0.482713
# eval accuracy (speed): 0.726064
# Starting epoch 97
# mean loss: 0.130585
# accuracy (angle): 0.451720
# accuracy (speed): 0.689484
# eval mean loss: 0.083724
# eval accuracy (angle): 0.481383
# eval accuracy (speed): 0.763298
# Starting epoch 98
# mean loss: 0.143521
# accuracy (angle): 0.440476
# accuracy (speed): 0.701389
# eval mean loss: 0.114613
# eval accuracy (angle): 0.404255
# eval accuracy (speed): 0.704787
# Starting epoch 99
# mean loss: 0.117889
# accuracy (angle): 0.476852
# accuracy (speed): 0.705357
# eval mean loss: 0.118504
# eval accuracy (angle): 0.449468
# eval accuracy (speed): 0.702128
